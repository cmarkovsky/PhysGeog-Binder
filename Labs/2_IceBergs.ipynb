# %% [markdown]
# # Lab 2: Greenland Icebergs
#
# In our journey into Python, we will now continue to build up our skill set by looking at icebergs. In this lab, we'll calculate a few different aspects of iceberg geometry and examine how these geometries affect the stability of the icebergs.

# %%
## Imports (Run this first!!)
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 - Rectangular
#
# ### 1.1 - Length, width, depth

# %%
dx = 50
L = np.arange(100, 1000 + dx, dx) # Iceberg Lengths

w = L / 1.62

D = 2.91 * L ** 0.71

# %% [markdown]
# ### 1.2 - Volume Under
#
# $$
# V_u = L*W*D = L * \frac{L}{1.62} * 2.91*L^{0.71}
# $$

# %%
### Fill-in and make this function. Make sure to add what you want to return

def calc_vol_under(L, w, D):

    Vu = 
    
    return Vu

### Write your code to calculate and print volume under here
Vu_rect =

# %% [markdown]
# ### 1.3 - Volume of Ice
#
# $$
# V_i = \frac{\rho_s}{\rho_i} * V_u
# $$

# %%
### Write your code to calculuate and print volume of ice here

Vi_rect =

# %% [markdown]
# ### 1.4 - Height
#
# $$
# H = \frac{1.62*(V_i - V_u)}{L^2}
# $$

# %%
### Write your code to calculuate and print height here

H_rect =

# %% [markdown]
# ### 1.5 - Stability
#
# $$
# S = \frac{w}{H+D}
# $$
# The iceberg will be stable if $S>0.92$, it will roll over if not.

# %%
### Write your code to calculuate 
def calc_stability(w, H, D):

    ### Write your function to calculate stability here
    S = 

    ### Fill in the inequality here 
    is_stable = S > 

    return S, is_stable

# Print the stability values and if each iceberg is stable here
S_rect, is_stable_rect =

# %% [markdown]
# ## 2 - Rectangular Pyramid
#
# ### 2.1 - Length, width, depth
#
# We will use the same $L$, $w$, and $D$ for each of the different ice berg shapes

# %% [markdown]
# ### 2.2 - Volume Under
#
# $$
# V_u = \frac{1}{3}*L*W*D = \frac{1}{3} * L * \frac{L}{1.62} * 2.91*L^{0.71}
# $$

# %%
### We can reuse our Volume under output from part 1. But this time, we want to multiply it by 1/3. 

### Write your code to calculate and print volume under here
Vu_pyr =

# %% [markdown]
# ### 2.3 - Volume of Ice
#
# $$
# V_i = \frac{\rho_s}{\rho_i} * V_u
# $$

# %%
### Write your code to calculuate and print volume of ice here
Vi_pyr

# %% [markdown]
# ### 2.4 - Height
#
# $$
# H = \frac{1.62*(V_i - V_u)}{L^2}
# $$

# %%
### Write your code to calculuate and print height here
H_pyr =

# %% [markdown]
# ### 2.5 - Stability
#
# $$
# S = \frac{W}{H+D}
# $$
# The iceberg will be stable if $S>0.92$, it will roll over if not.

# %%
### We can reuse our stability function from part 1 here. Write your code to calculuate and print height here
S_pyr, is_stable_pyr =

# %% [markdown]
# ## 3 - Cylinder
#
# ### 3.1 - Length, width, depth
#
# We will use the same $L$, $w$, and $D$ for each of the different ice berg shapes

# %% [markdown]
# ### 3.2 - Volume Under
#
# $$
# V_u = \pi * r^2 * H = \pi * (\frac{L}{2})^2 * D
# $$

# %%
### Fill-in and make this function. Make sure to add what you want to return

def calc_vol_under_cyl(L, w, D):
    
    Vu_cyl = np.pi *  
    
    return Vu_cyl

### Write your code to calculate and print volume under here
Vu_cyl =

# %% [markdown]
# ### 3.3 - Volume of Ice
#
# $$
# V_i = \frac{\rho_s}{\rho_i} * V_u
# $$

# %%
### Write your code to calculuate and print volume of ice here
Vi_cyl

# %% [markdown]
# ### 3.4 - Height
#
# $$
# H = 1.62*\frac{(V_i - V_u)}{\frac{\pi}{4}*L^2}
# $$

# %%
### Write your code to calculuate and print height here
H_cyl =

# %% [markdown]
# ### 3.5 - Stability
#
# $$
# S = \frac{W}{H+D}
# $$
# The iceberg will be stable if $S>0.92$, it will roll over if not.

# %%
### We can reuse our stability function from part 1 here. Write your code to calculuate and print height here
S_cyl, is_stable_cyl =

# %% [markdown]
# ## 4 - Cone
#
# ### 4.1 - Length, width, depth
#
# We will use the same $L$, $w$, and $D$ for each of the different ice berg shapes

# %% [markdown]
# ### 4.2 - Volume Under
#
# $$
# V_u = \frac{1}{3} * \pi * r^2 * H = \frac{1}{3}*\pi * (\frac{L}{2})^2 * D
# $$

# %%
### We can reuse our cylinder Volume under output from part 3. But this time, we want to multiply it by 1/3. 

### Write your code to calculate and print volume under here
Vu_con =

# %% [markdown]
# ### 4.3 - Volume of Ice
#
# $$
# V_i = \frac{\rho_s}{\rho_i} * V_u
# $$

# %%
### Write your code to calculuate and print volume of ice here
Vi_con

# %% [markdown]
# ### 4.4 - Height
#
# $$
# H = 1.62*\frac{(V_i - V_u)}{\frac{\pi}{4}*L^2}
# $$

# %%
### Write your code to calculuate and print height here
H_con =

# %% [markdown]
# ### 4.5 - Stability
#
# $$
# S = \frac{W}{H+D}
# $$
# The iceberg will be stable if $S>0.92$, it will roll over if not.

# %%
### We can reuse our stability function from part 1 here. Write your code to calculuate and print height here
S_cyl, is_stable_cyl =

# %% [markdown]
# ### Question 1!
# What do you notice about the stability for the rectangular prism and rectangular pyramid? How about the cylinder and cone? What are the similarities/differences between the different geometries and what aspect of the math impacts this? Answer in a few sentences below.

# %% [markdown]
# ## 5 - Plotting and Analysis
#
# ### 5.1 - Plotting Iceberg Volume

# %%
x = L
# y1 = Vi_rect
# y2 = Vi_pyr
# y3 = Vi_cyl
# y4 = Vi_con

fig, ax = plt.subplots(figsize = (10,6))

ax.scatter(x, y1, c = "red");
ax.scatter(x, , c = "blue"); # Fill in the y-value
ax.scatter(x, , c = "green"); # Fill in the y-value
ax.scatter(x, , c = 'grey'); # Fill in the y-value

ax.set_xlabel(""); # Fill in the quote to set the x-axis label
ax.set_ylabel(""); # Fill in the quote to set the y-axis label

plt.title(""); # Fill in the quote to set the title
plt.show()

# %% [markdown]
# ## 5.2 - Percent Difference

# %%
### Fill in this function to calculate the percent different between two iceberg volumes

def calc_percent_difference(V1, V2):

    per_diff = 
    
    return per_diff

# %%
### Write your code here to print the percent different between each iceberg geometry

# %% [markdown]
# ### Question 2!
# Does assumed geometry affect the calculation of freshwater coming from icebergs? Answer below in a couple of sentences
